# %%
# %matplotlib inline
import seaborn
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
plt.rcParams['figure.figsize'] = (13, 5)
import wave

# %% [markdown]
# # Understanding Audio Features through Sonification

# %% [markdown]
# 1. Detect onsets in an audio signal.
# 2. Segment the audio signal at each onset.
# 3. Compute features for each segment.
# 4. Gain intuition into the features by listening to each segment separately.

# %% [markdown]
# # Step 1: Retrieve Audio

# %%
x, sr = librosa.load('C:/Users/HIMANSHU GOYAL/Desktop/112_descending-clickers.wav')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-44416418e59f> in <module>()
# ----> 1 x, sr = librosa.load('C:/Users/HIMANSHU GOYAL/Desktop/112_descending-clickers.wav')
#
# C:\Users\HIMANSHU GOYAL\Anaconda2\lib\site-packages\librosa\core\audio.pyc in load(path, sr, mono, offset, duration, dtype, res_type)
#     119         n = 0
#     120
# --> 121         for frame in input_file:
#     122             frame = util.buf_to_float(frame, dtype=dtype)
#     123             n_prev = n
#
# C:\Users\HIMANSHU GOYAL\Anaconda2\lib\site-packages\audioread\rawread.pyc in read_data(self, block_samples)
#     110
#     111             # Make sure we have the desired bitdepth and endianness.
# --> 112             data = audioop.lin2lin(data, old_width, TARGET_WIDTH)
#     113             if self._needs_byteswap and self._file.getcomptype() != 'sowt':
#     114                 # Big-endian data. Swap endianness.
#
# error: Size should be 1, 2 or 4

# %%
print sr
# Out:
# 22050

# %%
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x, sr=sr)

# %% [markdown]
# Compute the short-time Fourier transform:

# %%
X = librosa.stft(x)

# %% [markdown]
# For display purposes, compute the log amplitude of the STFT:

# %%
Xmag = librosa.logamplitude(X)

# %% [markdown]
# Display the spectrogram.

# %%
librosa.display.specshow(Xmag, sr=sr, x_axis='time', y_axis='log')

# %% [markdown]
# # Step 2: Detect Onsets

# %% [markdown]
# Find the times, in seconds, when onsets occur in the audio signal.

# %%
onset_frames = librosa.onset.onset_detect(x, sr=sr)
print onset_frames
# Out:
# [12 33 55 66 76]

# %%
onset_times = librosa.frames_to_time(onset_frames, sr=sr)
print onset_times
# Out:
# [ 0.27863946  0.7662585   1.27709751  1.53251701  1.76471655]

# %% [markdown]
# Convert the onset frames into sample indices.

# %%
onset_samples = librosa.frames_to_samples(onset_frames)
print onset_samples
# Out:
# [ 6144 16896 28160 33792 38912]

# %% [markdown]
# Play a "beep" at each onset.

# %%
clicks = librosa.clicks(times=onset_times, length=len(x))

# %%
ipd.Audio(x+clicks, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Step 3: Segment the Audio

# %% [markdown]
# Save into an array, segments, 100-ms segments beginning at each onset.

# %%
frame_sz = int(0.100*sr)
segments = numpy.array([x[i:i+frame_sz] for i in onset_samples])

# %% [markdown]
# Here is a function that adds 300 ms of silence onto the end of each segment and concatenates them into one signal.
#
# Later, we will use this function to listen to each segment, perhaps sorted in a different order.

# %%
def concatenate_segments(segments, sr=22050, pad_time=0.300):
    padded_segments = [numpy.concatenate([segment, numpy.zeros(int(pad_time*sr))]) for segment in segments]
    return numpy.concatenate(padded_segments)

# %%
concatenated_signal = concatenate_segments(segments, sr)

# %% [markdown]
# Listen to the newly concatenated signal.

# %%
ipd.Audio(concatenated_signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Step 4: Extract Features

# %% [markdown]
# For each segment, compute the zero crossing rate.

# %%
zcrs = [sum(librosa.core.zero_crossings(segment)) for segment in segments]
print zcrs
# Out:
# [11, 570, 11, 10, 568]

# %% [markdown]
# Use argsort to find an index array, ind, such that segments[ind] is sorted by zero crossing rate.

# %%
ind = numpy.argsort(zcrs)
print ind
# Out:
# [3 0 2 4 1]

# %% [markdown]
# Sort the segments by zero crossing rate, and concatenate the sorted segments.

# %%
concatenated_signal = concatenate_segments(segments[ind], sr)

# %% [markdown]
# # Step 5: Listen to Segments

# %%
ipd.Audio(concatenated_signal, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature extraction

# %%
# %matplotlib inline
import seaborn
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
plt.rcParams['figure.figsize'] = (14, 5)

# %% [markdown]
# # Energy and RMSE

# %%
x, sr = librosa.load('C:/Users/HIMANSHU GOYAL/Downloads/audio files/ampli.wav')

# %%
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x, sr=sr)

# %%
hop_length = 256
frame_length = 1024

# %%
energy = numpy.array([
    sum(abs(x[i:i+frame_length]**2))
    for i in range(0, len(x), hop_length)
])

# %%
energy.size
# Out:
# 690

# %%
rmse = librosa.feature.rmse(x, frame_length=frame_length, hop_length=hop_length)[0]

# %%
rmse.size
# Out:
# 690

# %%
frames = range(len(energy))
t = librosa.frames_to_time(frames, sr=sr, hop_length=hop_length)

# %%
librosa.display.waveplot(x, sr=sr, alpha=0.4)
plt.plot(t, energy/energy.max(), 'r--')             # normalized for visualization
plt.plot(t[:len(rmse)], rmse/rmse.max(), color='g') # normalized for visualization
plt.legend(('Energy', 'RMSE'))

# %% [markdown]
# # Zero Crossing Rate

# %%
librosa.display.waveplot(x, sr=sr)

# %%
n0 = 6500
n1 = 7500
plt.plot(x[n0:n1])

# %%
zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)

# %%
zero_crossings.shape
# Out:
# (1000L,)

# %%
print sum(zero_crossings)
# Out:
# 42

# %% [markdown]
# # Magnitude Scaling

# %% [markdown]
# # amplitude

# %%
X = librosa.stft(x)
X.shape
# Out:
# (1025L, 345L)

# %% [markdown]
# # Pitch Transcription Exercise

# %%
bins_per_octave = 36
cqt = librosa.cqt(x, sr=sr, n_bins=300, bins_per_octave=bins_per_octave)
log_cqt = librosa.logamplitude(cqt)

# %%
cqt.shape
# Out:
# (300L, 345L)

# %%
librosa.display.specshow(log_cqt, sr=sr, x_axis='time', y_axis='cqt_note',bins_per_octave=bins_per_octave)

# %% [markdown]
# # Detect Onsets

# %%
hop_length = 100
onset_env = librosa.onset.onset_strength(x, sr=sr, hop_length=hop_length)

# %%
plt.plot(onset_env)
plt.xlim(0, len(onset_env))
# Out:
# (0, 1765)

# %%
onset_samples = librosa.onset.onset_detect(x,
                                           sr=sr, units='samples', 
                                           hop_length=hop_length, 
                                           backtrack=False,
                                           pre_max=20,
                                           post_max=20,
                                           pre_avg=100,
                                           post_avg=100,
                                           delta=0.2,
                                           wait=0)

# %%
print (onset_samples)
onset_samples.size
# Out:
# [  1300  13400  38400  56600  63100  87200 111900 136500]
# 8

# %%
onset_boundaries = numpy.concatenate([[0], onset_samples, [len(x)]])

# %%
print onset_boundaries
onset_boundaries.size
# Out:
# [     0   1300  13400  38400  56600  63100  87200 111900 136500 176400]
# 10

# %% [markdown]
# # Tempo Estimation

# %% [markdown]
# # Estimating Global Tempo

# %%
tempo = librosa.beat.tempo(x, sr=sr)
print tempo
tempo[0]
# Out:
# [ 107.66601562]
# 107.666015625

# %%
T = len(x)/float(sr)
seconds_per_beat = 60.0/tempo[0]
beat_times = numpy.arange(0, T, seconds_per_beat)

# %% [markdown]
# # Beat Tracking

# %%
tempo, beat_times = librosa.beat.beat_track(x, sr=sr, start_bpm=60, units='time')
print tempo
print beat_times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-46f45384a1e2> in <module>()
# ----> 1 tempo, beat_times = librosa.beat.beat_track(x, sr=sr, start_bpm=60, units='time')
#       2 print tempo
#       3 print beat_times
#
# NameError: name 'x' is not defined

# %%
import glob
import pandas as pd
import csv
import numpy as np
#import pydub

# %%
#arr=np.array(["file name","energy","zero cross","amplitude","pitch","global tempo","beat track"])
#arr

arr=["file name","energy","zero cross","amplitude","pitch","global tempo","beat track"]
arr
# Out:
# ['file name',
#  'energy',
#  'zero cross',
#  'amplitude',
#  'pitch',
#  'global tempo',
#  'beat track']

# %%
import wave 
"""file="C:/Users/HIMANSHU GOYAL/Desktop/all audios/not working/074_heartbeat-noise-machine.wav"
origAudio = wave.open("C:/Users/HIMANSHU GOYAL/Desktop/all audios/not working/074_heartbeat-noise-machine.wav","r")
frameRate = origAudio.getframerate()
nChannels = origAudio.getnchannels()
sampWidth = origAudio.getsampwidth()
nbframe=origAudio.getnframes()
da = np.fromstring(origAudio.readframes(48000), dtype=np.int16)
left, right = da[0::2], da[1::2]"""

#sox file.wav -b 16 file-2.wav
#sox file.wav -b 16 file-2.wav

#import soundfile
# Out:
# 'file="C:/Users/HIMANSHU GOYAL/Desktop/all audios/not working/074_heartbeat-noise-machine.wav"\norigAudio = wave.open("C:/Users/HIMANSHU GOYAL/Desktop/all audios/not working/074_heartbeat-noise-machine.wav","r")\nframeRate = origAudio.getframerate()\nnChannels = origAudio.getnchannels()\nsampWidth = origAudio.getsampwidth()\nnbframe=origAudio.getnframes()\nda = np.fromstring(origAudio.readframes(48000), dtype=np.int16)\nleft, right = da[0::2], da[1::2]'

# %%
def feature_extraction(audio):
    x,sr = librosa.load(audio)
    hop_length = 256
    frame_length = 1024
    energy = numpy.array([
        sum(abs(x[i:i+frame_length]**2))
        for i in range(0, len(x), hop_length)
    ])
    #energy.shape
    arr[1]=energy.size
    rmse = librosa.feature.rmse(x, frame_length=frame_length, hop_length=hop_length)[0]
    #rmse.shape

    frames = range(len(energy))
    t = librosa.frames_to_time(frames, sr=sr, hop_length=hop_length)
    n0 = 6500
    n1 = 7500
    zero_crossings = librosa.zero_crossings(x[n0:n1], pad=False)
    #print sum(zero_crossings)
    arr[2]=sum(zero_crossings)

    X = librosa.stft(x)
    #X.shape
    arr[3]=X.shape[1]

    bins_per_octave = 36
    cqt = librosa.cqt(x, sr=sr, n_bins=300, bins_per_octave=bins_per_octave)
    log_cqt = librosa.logamplitude(cqt)
    #cqt.shape
    hop_length = 100
    onset_env = librosa.onset.onset_strength(x, sr=sr, hop_length=hop_length)
    onset_samples = librosa.onset.onset_detect(x,
                                               sr=sr, units='samples', 
                                               hop_length=hop_length, 
                                               backtrack=False,
                                               pre_max=20,
                                               post_max=20,
                                               pre_avg=100,
                                               post_avg=100,
                                               delta=0.2,
                                               wait=0)
    #print (onset_samples)
    #onset_samples.size
    onset_boundaries = numpy.concatenate([[0], onset_samples, [len(x)]])
    #print onset_boundaries
    #onset_boundaries.size
    arr[4]=onset_samples.size

    tempo = librosa.beat.tempo(x, sr=sr)
    #print tempo
    T = len(x)/float(sr)
    seconds_per_beat = 60.0/tempo[0]
    beat_times = numpy.arange(0, T, seconds_per_beat)
    arr[5]=tempo[0]

    tempo, beat_times = librosa.beat.beat_track(x, sr=sr, start_bpm=60, units='time')
    #print tempo
    #print beat_times
    arr[6]=tempo




with open('C:/Users/HIMANSHU GOYAL/Downloads/extra/minor project implementation/data.csv', 'wb') as csvfile:
    arr=['file name','energy','zero cross','amplitude','pitch','global tempo','beat track']
    filewriter = csv.writer(csvfile, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    filewriter.writerow(arr)
    #files=glob.glob("C:/Users/HIMANSHU GOYAL/Downloads/audio files/*.wav")
    files=glob.glob("C:/Users/HIMANSHU GOYAL/Desktop/audio for training/*.wav")
    for file in files:
        arr[0]=file
        feature_extraction(file)
        print (arr)
        filewriter.writerow(arr)
    print("DONE")
# Out:
# C:\Users\HIMANSHU GOYAL\Anaconda2\lib\site-packages\librosa\util\utils.py:1725: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if np.issubdtype(x.dtype, float) or np.issubdtype(x.dtype, complex):
# C:\Users\HIMANSHU GOYAL\Anaconda2\lib\site-packages\librosa\util\utils.py:1725: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   if np.issubdtype(x.dtype, float) or np.issubdtype(x.dtype, complex):
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\100Hz_44100Hz_16bit_05sec.wav', 431, 10, 216L, 25, 123.046875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\100Hz_44100Hz_16bit_30sec.wav', 2584, 10, 1292L, 1, 123.046875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\100Hz_44100Hz_16bit_30seconds.wav', 2584, 10, 1292L, 1, 123.046875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\10kHz_44100Hz_16bit_30seconds.wav', 2584, 906, 1292L, 1, 129.19921875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\1kHz_44100Hz_16bit_05sec.wav', 431, 91, 216L, 2, 129.19921875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\1kHz_44100Hz_16bit_30sec.wav', 2584, 91, 1292L, 1, 123.046875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\250Hz_44100Hz_16bit_05sec.wav', 431, 23, 216L, 27, 143.5546875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\250Hz_44100Hz_16bit_30sec.wav', 2584, 23, 1292L, 1, 112.34714673913044, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\250Hz_44100Hz_16bit_30seconds.wav', 2584, 23, 1292L, 1, 112.34714673913044, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\440Hz_44100Hz_16bit_05sec.wav', 431, 40, 216L, 2, 112.34714673913044, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\440Hz_44100Hz_16bit_30sec.wav', 2584, 40, 1292L, 1, 112.34714673913044, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\Ambiguous-Bell.wav', 792, 47, 396L, 16, 123.046875, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\bell-tower.wav', 428, 36, 214L, 1, 135.99917763157896, 57.421875]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\brilliant-arresting-extravagant.wav', 280, 59, 140L, 10, 143.5546875, 66.25600961538461]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\cheesy-chimes.wav', 399, 627, 200L, 2, 151.99908088235293, 78.30255681818181]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\great-now-weve-got-time-to-party.wav', 273, 34, 137L, 6, 135.99917763157896, 66.25600961538461]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\healing-powers-work-at-long-range.wav', 293, 91, 147L, 5, 107.666015625, 107.666015625]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\imagine-yourself-nightmare-begins.wav', 1023, 70, 512L, 28, 129.19921875, 95.703125]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\interplay-sort-of-like-a-game.wav', 404, 44, 202L, 10, 123.046875, 80.74951171875]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\journey-comes-to-end-music-drama.wav', 281, 39, 141L, 13, 143.5546875, 58.72691761363637]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\mathematical-disasters-disrupt-patterns.wav', 612, 0, 306L, 26, 135.99917763157896, 60.09265988372093]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\meditation-jangle-bell.wav', 972, 536, 486L, 26, 117.45383522727273, 53.8330078125]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\not-a-dream-whats-happening-to-place.wav', 350, 170, 175L, 7, 92.28515625, 92.28515625]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\one-pretty-bell.wav', 517, 258, 259L, 3, 135.99917763157896, 0]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\one-round-bellhit.wav', 390, 39, 195L, 17, 129.19921875, 198.76802884615384]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\sweden-ball-hit.wav', 199, 440, 100L, 2, 161.4990234375, 198.76802884615384]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\tinkle-bright-bell.wav', 569, 474, 285L, 24, 99.38401442307692, 86.1328125]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\too-cute-bells.wav', 118, 512, 59L, 2, 161.4990234375, 287.109375]
# ['C:/Users/HIMANSHU GOYAL/Desktop/audio for training\\wobble-bell.wav', 773, 47, 387L, 11, 135.99917763157896, 0]
# DONE

# %%
files=glob.glob("C:/Users/HIMANSHU GOYAL/Desktop/all audios/*.wav")
for file in files:
    print (file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-72d9d8917146> in <module>()
# ----> 1 files=glob.glob("C:/Users/HIMANSHU GOYAL/Desktop/all audios/*.wav")
#       2 for file in files:
#       3     print (file)
#
# NameError: name 'glob' is not defined
